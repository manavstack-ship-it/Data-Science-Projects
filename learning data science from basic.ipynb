# %% [markdown]
# ## title

# %% [markdown]
# ## yellow

# %%
print("hello world")
# Out:
# hello world

# %%
"hello world""hello world"
# Out:
# 'hello worldhello world'

# %%
#my name
print("my name")
# Out:
# my name

# %%
type("hello boy")
# Out:
# str

# %%
print("hello boy".upper())
print("hello boy".title())
print("hello boy".lower())
# Out:
# HELLO BOY
# Hello Boy
# hello boy

# %%
"hello world".count('l')
# Out:
# 3

# %%
"hello world".replace('l','b')
# Out:
# 'hebbo worbd'

# %% [markdown]
# # varriable

# %%
message_1 = "I'm learnig python"

# %%
message_1
# Out:
# "I'm learnig python"

# %%
message_2= "and its fun"

# %%
message_2
# Out:
# 'its fun'

# %%
message_1 + message_2
# Out:
# "I'm learnig pythonand its fun"

# %%
message =message_1 +' '+ message_2
message
# Out:
# "I'm learnig python and its fun"

# %%
f'hello world'
# Out:
# 'hello world'

# %%
f'{message_1} abc {message_2}'
# Out:
# "I'm learnig python abc and its fun"

# %% [markdown]
# # list

# %%
countries =['united states','china','brazil','india']

# %%
countries
# Out:
# ['united states', 'china', 'brazil', 'india']

# %%
countries[0]
# Out:
# 'united states'

# %%
countries[1]
# Out:
# 'china'

# %%
print(countries[0])
print(countries[1])
print(countries[2])
print(countries[3])
# Out:
# united states
# china
# brazil
# india

# %%
countries[-1]
# Out:
# 'india'

# %%
countries[-3]
# Out:
# 'china'

# %%
# slicing
print("list-names[start:stop]")
# Out:
# list-names[start:stop]

# %%
countries[0:3]
# Out:
# ['united states', 'china', 'brazil']

# %%
countries[0:1]
# Out:
# ['united states']

# %%
countries[0:4]
# Out:
# ['united states', 'china', 'brazil', 'india']

# %% [markdown]
# ##### add eliments to list

# %%
countries
# Out:
# ['united states',
#  'china',
#  'brazil',
#  'india',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada']

# %%
countries.append('canada')

# %%
countries.insert(0, 'spain')

# %%
countries
# Out:
# ['spain',
#  'united states',
#  'china',
#  'brazil',
#  'india',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada']

# %%
countries_2 = ['uk','germany','iran']

# %%
countries_2
# Out:
# ['uk', 'germany', 'iran']

# %%
countries + countries_2
# Out:
# ['spain',
#  'united states',
#  'china',
#  'brazil',
#  'india',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'canada',
#  'uk',
#  'germany',
#  'iran']

# %%
nested_list = [countries_2,countries]

# %%
nested_list
# Out:
# [['uk', 'germany', 'iran'],
#  ['spain',
#   'united states',
#   'china',
#   'brazil',
#   'india',
#   'canada',
#   'canada',
#   'canada',
#   'canada',
#   'canada',
#   'canada',
#   'canada',
#   'canada',
#   'canada']]

# %%
countries =['united states','china','brazil','india']

# %%
countries.remove('united states')

# %%
countries
# Out:
# ['china', 'brazil', 'india']

# %%
countries.pop(-1)
# Out:
# 'india'

# %%
countries
# Out:
# ['china', 'brazil']

# %% [markdown]
# # dictinory

# %%
my_dic ={'key':'value','key2':'value2'}

# %%
my_data={'name':'manav','age':19}

# %%
"hello world""hello world"
# Out:
# 'hello worldhello world'

# %%
"hello world""hello world"
# Out:
# 'hello worldhello world'

# %%
my_data.values()
# Out:
# dict_values(['manav', 19])

# %%
my_data['height'] =  1.80

# %%
my_data.items()
# Out:
# dict_items([('name', 'manav'), ('age', 19), ('height', 1.8)])

# %%
my_data.update({'height':1.9})

# %%
my_data
# Out:
# {'name': 'manav', 'age': 19, 'height': 1.9}

# %% [markdown]
# # copy a dictionary

# %%
new_dict=my_data.copy()

# %%
new_dict
# Out:
# {'name': 'manav', 'age': 19, 'height': 1.9}

# %% [markdown]
# # remove item

# %%
my_data.pop('height')
# Out:
# 1.9

# %%
del my_data['age']

# %%
my_data
# Out:
# {'name': 'manav'}

# %%
my_data.clear()

# %%
my_data
# Out:
# {}

# %% [markdown]
# # if satatement

# %% [markdown]
# if<condition>:
#     <code>
# elif<condition>:
#     <code>
# ...
# else:
#     <code>

# %%
age=19

if age>=18:
    print("ur an adult")
elif age>=13:
    print("you are a teenager")

else:
    print("u a kid")
# Out:
# ur an adult

# %% [markdown]
# # for loop

# %% [markdown]
# for <variable> in <list>:
#     <code>

# %%
countries={'fiji','china','brazil','india'}

# %%
countries
# Out:
# {'brazil', 'china', 'fiji', 'india'}

# %%
for country in countries:
    print(country)
# Out:
# india
# fiji
# brazil
# china

# %%
for i,country in enumerate(countries):
    print(i)
    print(country)
# Out:
# 0
# india
# 1
# fiji
# 2
# brazil
# 3
# china

# %%
my_data={'name':'manav','age':19}
my_data
# Out:
# {'name': 'manav', 'age': 19}

# %% [markdown]
# # function

# %% [markdown]
# def funvtion(<params>):
#     <code>
#     return <data>

# %%
def sum_values(a,b):
    x=a+b
    return x

# %%
sum_values(1,3)
# Out:
# 4

# %% [markdown]
# # bulid in fuction

# %%
countries=['fiji','china','brazil','india']

# %%
len(countries)
# Out:
# 4

# %%
max([10,63,81,1,99])
# Out:
# 99

# %%
min([10,63,81,1,99])
# Out:
# 1

# %%
type(countries)
# Out:
# list

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# # os modules

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Manav\\anaconda_projects'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'codex.ipynb',
#  'codex2.ipynb',
#  'db',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %%
os.makedirs("new folder")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'codex.ipynb',
#  'codex2.ipynb',
#  'db',
#  'new folder',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %%
import pandas as pd
import numpy as np

# %%
# creating a array
data = np.array([[1,4],[2,5],[3,6]])

# %%
#create a data frame
df = pd.DataFrame(data,index=['batman','row2','row3'],
            columns=['superman','col2'])

# %%
#showing data frame
df
# Out:
#         superman  col2
# batman         1     4
# row2           2     5
# row3           3     6

# %%
#data frame without np
data=([[1,4],[2,5],[3,6]])

# %%
#create a data frame
df = pd.DataFrame(data,index=['batman','row2','row3'],
            columns=['superman','col2'])

# %%
df
# Out:
#         superman  col2
# batman         1     4
# row2           2     5
# row3           3     6

# %%
#creating data frames from dictionary
# list used for examples
states=['califonia','texas','florida','newyork']
population=[39613493, 29730311, 21944577, 19299981]

# %%
dict_states = {'States': states, 'Population': population}

# %%
df_population = pd.DataFrame(dict_states)

# %%
df_population
# Out:
#       States  Population
# 0  califonia    39613493
# 1      texas    29730311
# 2    florida    21944577
# 3    newyork    19299981

# %%
df_exams = pd.read_csv(r"C:\Users\Manav\Desktop\StudentsPerformance.csv")

# %%
#show first five rows
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#last 5 rows
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
#show last n rows
df_exams.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df_exams.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
#getting the shape attribuite to to find number of rows so i can display all the rows and columbs
df_exams.shape
# Out:
# (1000, 8)

# %%
#display all the n rows
pd.set_option('display.max_rows',1000)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
#pandas attribuites methods and functions
import pandas as pd

# %%
df_exams.shape
# Out:
# (1000, 8)

# %%
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#basic stats
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#functions
len(df_exams)
max(df_exams.index)
min(df_exams.index)
# Out:
# 0

# %%
max(df_exams.index)
# Out:
# 999

# %%
min(df_exams.index)
# Out:
# 0

# %%
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
round(df_exams,2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
import pandas as pd

# %%
#select a column
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
# 5      female
# 6      female
# 7        male
# 8        male
# 9      female
# 10       male
# 11       male
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# 20       male
# 21     female
# 22       male
# 23     female
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29     female
# 30     female
# 31     female
# 32     female
# 33       male
# 34       male
# 35       male
# 36     female
# 37     female
# 38     female
# 39       male
# 40       male
# 41     female
# 42     female
# 43       male
# 44     female
# 45       male
# 46     female
# 47     female
# 48     female
# 49       male
# 50       male
# 51       male
# 52       male
# 53       male
# 54     female
# 55     female
# 56     female
# 57       male
# 58       male
# 59     female
# 60       male
# 61       male
# ...

# %%
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
df_exams['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
import pandas as pd

# %%
df_exams = pd.read_csv(r"C:\Users\Manav\Desktop\StudentsPerformance.csv")

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#data types of each columbs
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#discribe basic stats
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#length rows only
len(df_exams)
# Out:
# 1000

# %%
max(df_exams.index)
# Out:
# 999

# %%
min(df_exams.index)
# Out:
# 0

# %%
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
round(df_exams)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
round(df_exams,2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#selecting one columb
import pandas as pd

# %%
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
df_exams['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams['gender'].index
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
import pandas as pd

# %%
#select 2 columbs
df_exams[['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
type(df_exams[['gender', 'math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
df_exams[['gender', 'math score','reading score','writing score']]
# Out:
#      gender  math score  reading score  writing score
# 0    female          72             72             74
# 1    female          69             90             88
# 2    female          90             95             93
# 3      male          47             57             44
# 4      male          76             78             75
# ..      ...         ...            ...            ...
# 995  female          88             99             95
# 996    male          62             55             55
# 997  female          59             71             65
# 998  female          68             78             77
# 999  female          77             86             86
#
# [1000 rows x 4 columns]

# %%
#create random integers between 1 and 100
import numpy as np

# %%
np.random.randint(1,100,size=1000)
# Out:
# array([ 9,  1, 33, 30, 44, 24, 57, 24, 48, 17, 46, 36, 46, 99, 49, 41, 36,
#        61, 87, 42, 80,  5, 19, 77, 75, 66, 78, 65, 97, 76, 40, 75, 90, 25,
#        89, 19, 14, 82, 37, 82, 84, 64, 23, 32, 60, 25, 49, 58, 92, 53, 20,
#        73, 31, 24,  5, 14,  3, 60, 80, 55, 20, 83, 69, 55, 58, 27, 65, 17,
#        66, 51, 94, 94, 61, 99, 83,  2, 88,  1, 79, 77, 30, 13, 80, 20, 79,
#        14, 87, 68, 10, 90, 59, 53, 24, 32, 67,  4, 80, 89, 98, 27, 82, 68,
#        48, 49, 70, 25, 81, 16, 19, 69,  3, 64, 59,  7, 13, 85,  5, 34, 77,
#        20, 81, 26, 72,  4, 45, 66, 33, 10, 35, 56, 30, 83, 12, 87, 88, 44,
#        51, 42, 32, 46, 59, 56, 85, 25, 73, 69, 54, 80, 83,  3, 42, 81, 92,
#         2, 71, 70, 84, 23, 91, 11, 97, 90, 72, 60, 35, 55, 59, 22, 56, 25,
#         3, 83, 26, 38,  4, 48,  4, 27, 15, 89, 52, 48, 79, 24, 35, 18,  8,
#        90, 29,  7, 92, 74, 42,  8, 28,  2, 80, 49, 16, 49, 23, 68, 64, 53,
# ...

# %%
len(np.random.randint(1,100,size=1000))
# Out:
# 1000

# %%
int_language_score=np.random.randint(1,100,size=1000)

# %%
min(int_language_score)
# Out:
# np.int32(1)

# %%
max(int_language_score)
# Out:
# np.int32(99)

# %%
df_exams['language score']=int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#create random float
np.random.uniform(1,100,size=100)
# Out:
# array([35.15201811, 13.199596  , 12.84622838, 25.30086147, 70.01784878,
#        27.79843731,  7.7181051 , 98.39023282, 57.17013564, 56.26987741,
#        73.23161759, 35.05351028, 18.45818901, 80.52512604, 71.96181359,
#        11.68787704, 87.98235304, 88.39290652, 72.09100304, 77.0391318 ,
#        36.02048477, 81.6178594 , 39.291678  , 32.96782299, 66.60022293,
#        42.33179539, 16.59244112, 72.41714489, 44.81095019, 91.75219364,
#        60.12822447, 74.45272046, 28.57671095, 71.39182966, 17.45703141,
#        42.69524884, 14.16135008, 38.60202847, 62.01718361, 33.54502752,
#        51.08671933, 26.24253706, 88.69502113, 78.36250778, 74.0808    ,
#        84.16553415,  9.24566326, 72.98013428, 68.35641253, 69.2802953 ,
#        15.17899999, 69.8601424 , 11.34553199, 68.82814436, 64.74279091,
#        28.47226743, 20.40550011, 50.76380839, 52.26587838, 67.38654259,
#        35.60423448, 11.35225534, 26.6242882 , 41.82347434,  3.43182295,
# ...

# %%
df_exams=pd.read_csv(r"C:\Users\Manav\Desktop\StudentsPerformance.csv")

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
import numpy as np

# %%
#add new colums
score1=np.random.randint(1,100,size=1000)
score2=np.random.randint(1,100,size=1000)

# %%
series1 = pd.Series(score1, index=np.arange(0, 1000)) 
series2 = pd.Series(score2, index=np.arange(0, 1000))

# %%
series1
# Out:
# 0      92
# 1      40
# 2      40
# 3      31
# 4       3
#        ..
# 995    46
# 996    28
# 997    22
# 998    93
# 999    77
# Length: 1000, dtype: int32

# %%
df_exams.assign(score1=series1,score2=series2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# ...

# %%
df_exams=df_exams.assign(score1=series1,score2=series2)

# %%
#insert method
df_exams.insert(1,'test',series1)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    92        group B           bachelor's degree      standard
# 1    female    40        group C                some college      standard
# 2    female    40        group B             master's degree      standard
# 3      male    31        group A          associate's degree  free/reduced
# 4      male     3        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    46        group E             master's degree      standard
# 996    male    28        group C                 high school  free/reduced
# 997  female    22        group C                 high school  free/reduced
# 998  female    93        group D                some college      standard
# 999  female    77        group D                some college  free/reduced
#
# ...

# %%
#math operations
df_exams['math score'].sum()
# Out:
# np.int64(66089)

# %%
import pandas as pd

# %%
import numpy as np

# %%
df_exams = pd.read_csv(r"C:\Users\Manav\Desktop\StudentsPerformance.csv")

# %%
#math operations
df_exams['math score'].max()
# Out:
# 100

# %%
#math operations
df_exams['math score'].min()
# Out:
# 0

# %%
#math operations
#math operations
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#operations in rows
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
df_exams['average']=(df_exams['math score'] + df_exams['reading score'] + df_exams['writing score'])/3

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score    average
# 0                    none          72             72             74  72.666667
# 1               completed          69             90             88  82.333333
# 2                    none          90             95             93  92.666667
# 3                    none          47             57             44  49.333333
# 4                    none          76             78             75  76.333333

# %%
df_exams.round(2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  average
# ...

# %%
#counting gender element
df_exams['gender'].value_counts()
#len function
len(df_exams['gender'])
#.count()method
df_exams['gender'].count()

# %%
df_exams['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df_exams['gender'].value_counts(normalize='true')
# Out:
# gender
# female    0.518
# male      0.482
# Name: proportion, dtype: float64

# %%
#count element by category
df_exams['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
df_exams['parental level of education'].value_counts(normalize='true')
# Out:
# parental level of education
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: proportion, dtype: float64

# %%
import pandas as pd

# %%
df_exams=pd.read_csv(r"C:\Users\Manav\Desktop\StudentsPerformance.csv")

# %%
df_exams['parental level of education'].value_counts(normalize='true')
# Out:
# parental level of education
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: proportion, dtype: float64

# %%
df_exams['parental level of education'].value_counts(normalize='true')
