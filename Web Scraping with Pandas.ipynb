# %%
#target website football-data.uk

# %%
import pandas as pd

# %%
#reading csv file
pd.read_csv('https://www.football-data.co.uk/mmz4281/2122/E0.csv')
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E0  13/08/2021  20:00       Brentford         Arsenal     2     0   H
# 1    E0  14/08/2021  12:30      Man United           Leeds     5     1   H
# 2    E0  14/08/2021  15:00         Burnley        Brighton     1     2   A
# 3    E0  14/08/2021  15:00         Chelsea  Crystal Palace     3     0   H
# 4    E0  14/08/2021  15:00         Everton     Southampton     3     1   H
# ..   ..         ...    ...             ...             ...   ...   ...  ..
# 375  E0  22/05/2022  16:00  Crystal Palace      Man United     1     0   H
# 376  E0  22/05/2022  16:00       Leicester     Southampton     4     1   H
# 377  E0  22/05/2022  16:00       Liverpool          Wolves     3     1   H
# 378  E0  22/05/2022  16:00        Man City     Aston Villa     3     2   H
# 379  E0  22/05/2022  16:00         Norwich       Tottenham     0     5   A
#
# ...

# %%
df_premier21=pd.read_csv('https://www.football-data.co.uk/mmz4281/2122/E0.csv')

# %%
df_premier21
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E0  13/08/2021  20:00       Brentford         Arsenal     2     0   H
# 1    E0  14/08/2021  12:30      Man United           Leeds     5     1   H
# 2    E0  14/08/2021  15:00         Burnley        Brighton     1     2   A
# 3    E0  14/08/2021  15:00         Chelsea  Crystal Palace     3     0   H
# 4    E0  14/08/2021  15:00         Everton     Southampton     3     1   H
# ..   ..         ...    ...             ...             ...   ...   ...  ..
# 375  E0  22/05/2022  16:00  Crystal Palace      Man United     1     0   H
# 376  E0  22/05/2022  16:00       Leicester     Southampton     4     1   H
# 377  E0  22/05/2022  16:00       Liverpool          Wolves     3     1   H
# 378  E0  22/05/2022  16:00        Man City     Aston Villa     3     2   H
# 379  E0  22/05/2022  16:00         Norwich       Tottenham     0     5   A
#
# ...

# %%
#change the name of columbs
df_premier21.rename(
    columns={'FTHG': 'home_goals', 'FTAG': 'away_goals'},
    inplace=True
)

# %%
df_premier21
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  home_goals  \
# 0    E0  13/08/2021  20:00       Brentford         Arsenal           2
# 1    E0  14/08/2021  12:30      Man United           Leeds           5
# 2    E0  14/08/2021  15:00         Burnley        Brighton           1
# 3    E0  14/08/2021  15:00         Chelsea  Crystal Palace           3
# 4    E0  14/08/2021  15:00         Everton     Southampton           3
# ..   ..         ...    ...             ...             ...         ...
# 375  E0  22/05/2022  16:00  Crystal Palace      Man United           1
# 376  E0  22/05/2022  16:00       Leicester     Southampton           4
# 377  E0  22/05/2022  16:00       Liverpool          Wolves           3
# 378  E0  22/05/2022  16:00        Man City     Aston Villa           3
# 379  E0  22/05/2022  16:00         Norwich       Tottenham           0
#
#      away_goals FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# ...

# %% [markdown]
# ## multiple urls

# %%
#create a root variable
https://www.football-data.co.uk/mmz4281/2122/E0.csv
https://www.football-data.co.uk/mmz4281/2425/E1.csv

# %%
#create a root variable
root="https://www.football-data.co.uk/mmz4281/"

# %%
import pandas as pd

# %%
#creating list of leagues
leagues=['E0','E1','E2','E3','EC']
frames=[]
#for looping through lists
for league in leagues:
    df=pd.read_csv(root+'2122'+'/'+league+'.csv',encoding='unicode_escape')
    frames.append(df)

# %%
len(frames)
# Out:
# 5

# %%
frames[0]
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E0  13/08/2021  20:00       Brentford         Arsenal     2     0   H
# 1    E0  14/08/2021  12:30      Man United           Leeds     5     1   H
# 2    E0  14/08/2021  15:00         Burnley        Brighton     1     2   A
# 3    E0  14/08/2021  15:00         Chelsea  Crystal Palace     3     0   H
# 4    E0  14/08/2021  15:00         Everton     Southampton     3     1   H
# ..   ..         ...    ...             ...             ...   ...   ...  ..
# 375  E0  22/05/2022  16:00  Crystal Palace      Man United     1     0   H
# 376  E0  22/05/2022  16:00       Leicester     Southampton     4     1   H
# 377  E0  22/05/2022  16:00       Liverpool          Wolves     3     1   H
# 378  E0  22/05/2022  16:00        Man City     Aston Villa     3     2   H
# 379  E0  22/05/2022  16:00         Norwich       Tottenham     0     5   A
#
# ...

# %%
frames[4]
# Out:
#     Div        Date   Time        HomeTeam      AwayTeam  FTHG  FTAG FTR  \
# 0    EC  21/08/2021  15:00       Aldershot  Chesterfield     0     2   A
# 1    EC  21/08/2021  15:00          Barnet  Notts County     0     5   A
# 2    EC  21/08/2021  15:00         Halifax    Maidenhead     1     2   A
# 3    EC  21/08/2021  15:00     Kings Lynn      Southend     0     1   A
# 4    EC  21/08/2021  15:00        Solihull       Wrexham     2     2   D
# ..   ..         ...    ...             ...           ...   ...   ...  ..
# 501  EC  15/05/2022  15:00  Dover Athletic      Weymouth     1     2   A
# 502  EC  15/05/2022  15:00       Eastleigh       Grimsby     4     4   D
# 503  EC  15/05/2022  15:00      Maidenhead  Notts County     0     1   A
# 504  EC  15/05/2022  15:00        Southend       Torquay     1     1   D
# 505  EC  15/05/2022  15:00       Stockport       Halifax     2     0   H
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# ...

# %%
for season in range(15,21):
    print (season)
# Out:
# 15
# 16
# 17
# 18
# 19
# 20

# %%
#for loop for seasons
#creating list of leagues
leagues=['E0','E1','E2','E3','EC']
frames=[]
#for looping through lists
for league in leagues:
    for season in range(15,21):
        df=pd.read_csv(root+'2122'+'/'+league+'.csv',encoding='unicode_escape')
        frames.append(df)

# %%
for season in range(15,21):
    print (str(season)+str(season+1))
# Out:
# 1516
# 1617
# 1718
# 1819
# 1920
# 2021

# %%
leagues = ['E0','E2', 'E3']

frames = []

# loop through range of seasons and insert new column
for league in leagues:
    for season in range(15,21): # range of seasons
        df = pd.read_csv(root + str(season) + str(season+1) + "/" + league + ".csv")
#         df['season'] = season
        df.insert(1, 'season', season)
        frames.append(df)

# %%
len(frames)
# Out:
# 18

# %%
frames[0]
# Out:
#     Div  season        Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0      15  08/08/2015  Bournemouth  Aston Villa     0     1   A     0
# 1    E0      15  08/08/2015      Chelsea      Swansea     2     2   D     2
# 2    E0      15  08/08/2015      Everton      Watford     2     2   D     0
# 3    E0      15  08/08/2015    Leicester   Sunderland     4     2   H     3
# 4    E0      15  08/08/2015   Man United    Tottenham     1     0   H     1
# ..   ..     ...         ...          ...          ...   ...   ...  ..   ...
# 375  E0      15  15/05/2016        Stoke     West Ham     2     1   H     0
# 376  E0      15  15/05/2016      Swansea     Man City     1     1   D     1
# 377  E0      15  15/05/2016      Watford   Sunderland     2     2   D     0
# 378  E0      15  15/05/2016    West Brom    Liverpool     1     1   D     1
# 379  E0      15  17/05/2016   Man United  Bournemouth     3     1   H     1
#
# ...

# %%
frames[17]
# Out:
#     Div  season        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG  \
# 0    E3      20  12/09/2020  15:00      Barrow       Stevenage     1     1
# 1    E3      20  12/09/2020  15:00      Bolton    Forest Green     0     1
# 2    E3      20  12/09/2020  15:00    Bradford      Colchester     0     0
# 3    E3      20  12/09/2020  15:00   Cambridge        Carlisle     3     0
# 4    E3      20  12/09/2020  15:00  Cheltenham       Morecambe     1     2
# ..   ..     ...         ...    ...         ...             ...   ...   ...
# 547  E3      20  08/05/2021  15:00   Port Vale       Mansfield     0     3
# 548  E3      20  08/05/2021  15:00  Scunthorpe       Stevenage     0     1
# 549  E3      20  08/05/2021  15:00    Southend  Newport County     1     1
# 550  E3      20  08/05/2021  15:00    Tranmere      Colchester     0     0
# 551  E3      20  08/05/2021  16:00     Salford   Leyton Orient     3     0
#
# ...

# %% [markdown]
# ## organise the data

# %%
dict_countries = {
              'Spanish La Liga':'SP1', 'Spanish Segunda Division':'SP2',
              'German Bundesliga':'D1', 
              'English Premier League':'E0', 'English League 1':'E2', 'English League 2':'E3',
             }

# %%
dict_historical_data = {} 

# looping through key elements
for league in dict_countries:
    frames = [] # one dataframe per league
    for season in range(15, 21):
        df = pd.read_csv(root + str(season) + str(season+1) + "/" + dict_countries[league]+ ".csv")
        df.insert(1, 'season', season)
        frames.append(df)
    df_frames = pd.concat(frames) # storing all seasons of a league in a single dataframe
    dict_historical_data[league] = df_frames # assigning dataframe to a new dictionary

# %%
#dict_historical_data
dict_historical_data['Spanish La Liga']
# Out:
#      Div  season        Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    SP1      15    21/08/15       Malaga     Sevilla     0     0   D     0
# 1    SP1      15    22/08/15   Ath Madrid  Las Palmas     1     0   H     1
# 2    SP1      15    22/08/15      Espanol      Getafe     1     0   H     1
# 3    SP1      15    22/08/15    La Coruna    Sociedad     0     0   D     0
# 4    SP1      15    22/08/15    Vallecano    Valencia     0     0   D     0
# ..   ...     ...         ...          ...         ...   ...   ...  ..   ...
# 375  SP1      20  22/05/2021      Osasuna    Sociedad     0     1   A     0
# 376  SP1      20  22/05/2021  Real Madrid  Villarreal     2     1   H     0
# 377  SP1      20  22/05/2021   Valladolid  Ath Madrid     1     2   A     1
# 378  SP1      20  23/05/2021      Granada      Getafe     0     0   D     0
# 379  SP1      20  23/05/2021      Sevilla      Alaves     1     0   H     0
#
# ...

# %%
import pandas as pd

# %%
df_laptops=pd.read_csv(laptop_data.csv)

# %%
df_laptops
# Out:
#         Brand             Model           CPU  RAM_GB  Storage_GB         GPU  \
# 0       Apple       MacBook Air            M4      16         512  Integrated
# 1        ASUS       Vivobook 16  Core Ultra 5      16         512  Integrated
# 2      Lenovo    IdeaPad Slim 3       Ryzen 5       8         256  Integrated
# 3        Acer      Aspire Go 15    Intel N100       8         128  Integrated
# 4          HP         Victus 15       Ryzen 5      16         512    RTX 5050
# 5        Dell       Inspiron 14  Core Ultra 7      16        1024  Integrated
# 6        ASUS    TUF Gaming A16       Ryzen 7      16        1024    RTX 5060
# 7      Lenovo           Yoga 7i  Core Ultra 5      16         512  Integrated
# 8       Apple    MacBook Pro 14        M4 Pro      24         512  Integrated
# 9        Acer        Nitro V 16       Ryzen 7      16         512    RTX 5050
# 10        MSI         Cyborg 15  Core i7-13th      16         512    RTX 4050
# ...

# %%
df_laptops.head(3)
# Out:
#     Brand           Model           CPU  RAM_GB  Storage_GB         GPU  \
# 0   Apple     MacBook Air            M4      16         512  Integrated
# 1    ASUS     Vivobook 16  Core Ultra 5      16         512  Integrated
# 2  Lenovo  IdeaPad Slim 3       Ryzen 5       8         256  Integrated
#
#    Price_USD Category
# 0       1299  Premium
# 1        649   Budget
# 2        429   Budget

# %%
#filter a data frame
df_laptops['Brand']=="Apple"
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: Brand, dtype: bool

# %%
# filter dataframe based on condition
df_laptops[df_laptops['Brand']=='Apple']
# Out:
#     Brand           Model     CPU  RAM_GB  Storage_GB         GPU  Price_USD  \
# 0   Apple     MacBook Air      M4      16         512  Integrated       1299
# 8   Apple  MacBook Pro 14  M4 Pro      24         512  Integrated       1999
# 24  Apple  MacBook Pro 16  M4 Max      48        1024  Integrated       3499
#
#         Category
# 0        Premium
# 8   Professional
# 24  Professional

# %%
# verify which companies are in the "Company" column with value_counts()
df_laptops[df_laptops['Brand']=='Apple'].value_counts('Brand')
# Out:
# Brand
# Apple    3
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
df_laptops=pd.read_csv(r"C:\Users\Manav\Downloads\laptop_data.csv")

# %%
df_laptops.head(5)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df_laptops['Company']=="Apple"
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
#filter on basis of company
df_laptops[df_laptops['Company']=='Apple']
# Out:
#       Unnamed: 0 Company   TypeName  Inches  \
# 0              0   Apple  Ultrabook    13.3
# 1              1   Apple  Ultrabook    13.3
# 3              3   Apple  Ultrabook    15.4
# 4              4   Apple  Ultrabook    13.3
# 6              6   Apple  Ultrabook    15.4
# 7              7   Apple  Ultrabook    13.3
# 12            12   Apple  Ultrabook    15.4
# 14            14   Apple  Ultrabook    12.0
# 15            15   Apple  Ultrabook    13.3
# 17            17   Apple  Ultrabook    15.4
# 26            26   Apple  Ultrabook    13.3
# 34            34   Apple  Ultrabook    13.3
# 45            45   Apple  Ultrabook    13.3
# 81            81   Apple  Ultrabook    12.0
# 249          249   Apple  Ultrabook    13.3
# 270          270   Apple  Ultrabook    13.3
# 794          794   Apple  Ultrabook    12.0
# 1069        1069   Apple  Ultrabook    12.0
# 1193        1193   Apple  Ultrabook    12.0
# 1210        1210   Apple  Ultrabook    12.0
# ...

# %%
df_laptops[df_laptops['Company']=='Apple'].value_counts('Company')
# Out:
# Company
# Apple    21
# Name: count, dtype: int64

# %%
#which rows dont have the hp columbs
df_laptops['Company']=="Hp"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
df_laptops['Company']!="Hp"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1298    True
# 1299    True
# 1300    True
# 1301    True
# 1302    True
# Name: Company, Length: 1303, dtype: bool

# %%
df_laptops=pd.read_csv(r"C:\Users\Manav\Downloads\laptop_data.csv")

# %%
df_laptops['Company']!="HP"
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1298     True
# 1299     True
# 1300     True
# 1301    False
# 1302     True
# Name: Company, Length: 1303, dtype: bool

# %%
#filter hp out
df_laptops[df_laptops['Company']!="HP"].value_counts('Company')
# Out:
# Company
# Lenovo       297
# Dell         297
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Google         3
# LG             3
# Fujitsu        3
# Huawei         2
# Name: count, dtype: int64

# %%
#find laptop with price over 2000 euroes
df_laptops[df_laptops['Price']>2000]
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
len(df_laptops[df_laptops['Price']>2000])
# Out:
# 1303

# %%
df_laptops['Price'].round()
# Out:
# 0        71379.0
# 1        47896.0
# 2        30636.0
# 3       135195.0
# 4        96096.0
#           ...
# 1298     33993.0
# 1299     79867.0
# 1300     12201.0
# 1301     40706.0
# 1302     19660.0
# Name: Price, Length: 1303, dtype: float64

# %%
df_laptops[['Price']] = df_laptops[['Price']].round()

# %%
df_laptops.head(5)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight     Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71379.0
# ...

# %%
len(df_laptops[df_laptops['Price']>50000])
# Out:
# 680

# %%
df_laptops[df_laptops['Price']>50000]
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# 6              6   Apple           Ultrabook    15.4
# 7              7   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1256        1256    Asus              Gaming    17.3
# 1259        1259     MSI              Gaming    15.6
# 1271        1271  Lenovo  2 in 1 Convertible    13.3
# 1285        1285  Lenovo  2 in 1 Convertible    13.3
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                          Cpu  \
# 0             IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz
# 3             IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz
# 4             IPS Panel Retina Display 2560x1600         Intel Core i5 3.1GHz
# ...

# %%
import numpy as np
